# %%
import urllib
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from urllib.request import urlopen
import cv2
from imutils import paths

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.layers import Conv2D,Flatten,MaxPooling2D,Dense,Dropout,SpatialDropout2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array,load_img,array_to_img
import os

# %%
dir_path='C:\dl_proje\Brain_tumor'

# %%
target_size=(224,224)
waste_label={'no':0,'yes':1}

# %%
def load_datasets(path):
    "görsellerin bulundugu dizindeki görüntüyü okuyup etiketleri olusturur"
    "parametreler:"
    "x:goruntulere ait matris bilgilerini tutar"
    "labels:görüntunun ait oldugu sınıf bilgisini tutan liste"
    x=[]
    labels=[]
    image_paths=sorted(list(paths.list_images(path)))
    for image_path in image_paths:
        img=cv2.imread(image_path)
        img=cv2.resize(img,target_size)
        x.append(img)
        label=image_path.split(os.path.sep)[-2]
        labels.append(waste_label[label])
    x,labels=shuffle(x,labels,random_state=42)
    print(f'xin boyutu{np.array(x).shape}')
    print(f'label sınıf sayısı {len(np.unique(labels))},gözlem sayısı {len(labels)}')
    return x,labels

# %%
x,labels=load_datasets(dir_path)
# Out:
# xin boyutu(253, 224, 224, 3)
# label sınıf sayısı 2,gözlem sayısı 253

# %%
def goruntule(image_1,label_1):
    plt.figure(figsize=(8,8))
    for i in range(10):
        ax=plt.subplot(2,5,i+1)
        plt.imshow(image_1[i])
        plt.title(np.array(list(waste_label.keys()))[to_categorical(label_1,num_classes=2)[i]==1][0].title())
        plt.axis('off')

# %%
goruntule(x,labels)

# %%
#IMAGEDATAGENERATOR FONKSİYONUN GÖREVİ VERİ ÜRETMEKTİR,KÜÇÜK BİR GÖRÜNTÜ KÜMESİNDEN ÇEŞİTLİ VERİ ÜRETİR
#GÖRÜNTÜLERE GÖRÜNTÜ ÇEŞİTLENDİRME TEKNİKLERİ UYGULAYARAK GERÇEK DÜNYADAKİ GİBİ BİR HAL VERECEĞİZ
train=ImageDataGenerator(
    horizontal_flip=True,#görüntüleri rastgele yatay olarak cevirmekte
    vertical_flip=True,#dikey olarak
    validation_split=0.1,#test veri setinin oranı
    rescale=1./255,#yeniden ölçeklendirme,resimleri 0 ile 1 arasına ölçeklendiriyor
    shear_range=0.1,#görüntünün şekline eğim veriyor
    zoom_range=0.1,#genişlik kaydırma
    height_shift_range=0.1,
    width_shift_range=0.1
    
)

test=ImageDataGenerator(
    rescale=1./255,
    validation_split=0.5
)

# %%
train_generator=train.flow_from_directory(
    directory=dir_path,
    target_size=(target_size),
    class_mode='binary',
    subset='training'
    
)

test_generator=test.flow_from_directory(directory=dir_path,
                                        target_size=(target_size),
                                        class_mode='binary',
                                        subset='validation',
                                        batch_size=6
                                       )
# Out:
# Found 228 images belonging to 2 classes.
# Found 126 images belonging to 2 classes.

# %%
input_shape=(224,224,3)

# %%
model=Sequential()

# %%
model.add(Conv2D(
    filters=28,
    kernel_size=(2,2),
    padding='same',
    input_shape=(input_shape),
    activation='relu'
    
    
))

model.add(MaxPooling2D(
    pool_size=2,
    strides=(2,2)
    
))

model.add(Conv2D(
    filters=56,
    kernel_size=(2,2),
    padding='same',
    input_shape=(input_shape),
    activation='relu'
    
    
))

model.add(MaxPooling2D(
    pool_size=2,
    strides=(2,2)
    
))

model.add(Conv2D(
    filters=28,
    kernel_size=(2,2),
    padding='same',
    input_shape=(input_shape),
    activation='relu'
    
    
))

model.add(MaxPooling2D(
    pool_size=2,
    strides=(2,2)
    
))

# %%
model.add(Flatten())

# %%
model.add(Dense(units=48,activation='relu'))
model.add(Dropout(rate=0.1))
model.add(Dense(units=24,activation='relu'))
model.add(Dropout(rate=0.1))
model.add(Dense(units=1,activation='sigmoid'))
model.add(Dropout(rate=0.1))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)                    │ (None, 224, 224, 28)        │             364 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 112, 112, 28)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 112, 112, 56)        │           6,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 56, 56, 56)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 56, 56, 28)          │           6,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 28, 28, 28)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 21952)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 48)                  │       1,053,744 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 48)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 24)                  │           1,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 24)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 2)                   │              50 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 2)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 48)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 48)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 24)                  │           1,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 24)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 2)                   │              50 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 2)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 48)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 48)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 24)                  │           1,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 24)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 1)                   │              25 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 1)                   │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,070,677 (4.08 MB)
#  Trainable params: 1,070,677 (4.08 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=[tf.keras.metrics.Precision(),tf.keras.metrics.Recall(),'acc']
)

callbacks=[EarlyStopping(monitor='acc',patience=10,mode='max',verbose=1)]

# %%
history=model.fit(train_generator,
                 validation_data=test_generator,
                 epochs=40,
                  callbacks=callbacks,

                  
                 )
# Out:
# Epoch 1/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - acc: 0.8601 - loss: 2.2551 - precision_2: 1.0000 - recall_2: 0.8601 - val_acc: 1.0000 - val_loss: 0.0017 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 2/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 347ms/step - acc: 0.8971 - loss: 1.6587 - precision_2: 1.0000 - recall_2: 0.8971 - val_acc: 1.0000 - val_loss: 0.0015 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 3/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 351ms/step - acc: 0.9108 - loss: 1.4376 - precision_2: 1.0000 - recall_2: 0.9108 - val_acc: 1.0000 - val_loss: 0.0014 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 4/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 340ms/step - acc: 0.8923 - loss: 1.7352 - precision_2: 1.0000 - recall_2: 0.8923 - val_acc: 1.0000 - val_loss: 0.0013 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 5/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 359ms/step - acc: 0.9271 - loss: 1.1754 - precision_2: 1.0000 - recall_2: 0.9271 - val_acc: 1.0000 - val_loss: 0.0013 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 6/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 364ms/step - acc: 0.8920 - loss: 1.7411 - precision_2: 1.0000 - recall_2: 0.8920 - val_acc: 1.0000 - val_loss: 0.0013 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 7/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 346ms/step - acc: 0.9035 - loss: 1.5565 - precision_2: 1.0000 - recall_2: 0.9035 - val_acc: 1.0000 - val_loss: 0.0012 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 8/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 356ms/step - acc: 0.8893 - loss: 1.7842 - precision_2: 1.0000 - recall_2: 0.8893 - val_acc: 1.0000 - val_loss: 0.0011 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 9/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 349ms/step - acc: 0.9048 - loss: 1.5356 - precision_2: 1.0000 - recall_2: 0.9048 - val_acc: 1.0000 - val_loss: 9.6215e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 10/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - acc: 0.9232 - loss: 1.2386 - precision_2: 1.0000 - recall_2: 0.9232 - val_acc: 1.0000 - val_loss: 8.8407e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 11/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - acc: 0.8822 - loss: 1.8982 - precision_2: 1.0000 - recall_2: 0.8822 - val_acc: 1.0000 - val_loss: 8.2051e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 12/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 346ms/step - acc: 0.9465 - loss: 0.8618 - precision_2: 1.0000 - recall_2: 0.9465 - val_acc: 1.0000 - val_loss: 7.9366e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 13/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 346ms/step - acc: 0.8817 - loss: 1.9072 - precision_2: 1.0000 - recall_2: 0.8817 - val_acc: 1.0000 - val_loss: 7.8206e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 14/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 350ms/step - acc: 0.9168 - loss: 1.3415 - precision_2: 1.0000 - recall_2: 0.9168 - val_acc: 1.0000 - val_loss: 7.5056e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 15/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 346ms/step - acc: 0.9014 - loss: 1.5891 - precision_2: 1.0000 - recall_2: 0.9014 - val_acc: 1.0000 - val_loss: 7.0018e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 16/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 343ms/step - acc: 0.8798 - loss: 1.9367 - precision_2: 1.0000 - recall_2: 0.8798 - val_acc: 1.0000 - val_loss: 6.6306e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 17/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 348ms/step - acc: 0.9050 - loss: 1.5311 - precision_2: 1.0000 - recall_2: 0.9050 - val_acc: 1.0000 - val_loss: 6.3025e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 18/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 347ms/step - acc: 0.8769 - loss: 1.9842 - precision_2: 1.0000 - recall_2: 0.8769 - val_acc: 1.0000 - val_loss: 6.1627e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 19/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 344ms/step - acc: 0.9445 - loss: 0.8950 - precision_2: 1.0000 - recall_2: 0.9445 - val_acc: 1.0000 - val_loss: 5.9941e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 20/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 398ms/step - acc: 0.8898 - loss: 1.7760 - precision_2: 1.0000 - recall_2: 0.8898 - val_acc: 1.0000 - val_loss: 5.4366e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 21/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 397ms/step - acc: 0.8735 - loss: 2.0391 - precision_2: 1.0000 - recall_2: 0.8735 - val_acc: 1.0000 - val_loss: 5.2063e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 22/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 353ms/step - acc: 0.8802 - loss: 1.9305 - precision_2: 1.0000 - recall_2: 0.8802 - val_acc: 1.0000 - val_loss: 5.1080e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 22: early stopping

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['acc'],label='Train doğruluk oranı')
plt.plot(history.history['val_acc'],label='Test verisi doğruluk oranı')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'],label='Train loss')
plt.plot(history.history['val_loss'],label='Test loss')
plt.legend()
plt.show()
